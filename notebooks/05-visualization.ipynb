# %% [markdown]
# # 05: Visualization & React-Ready Exports
#
# This notebook demonstrates exporting geospatial results for dashboards and React applications.
#
# **Topics:**
# - Export to GeoJSON
# - Create interactive Plotly maps
# - Generate React-compatible JSON
# - Export to Folium/Leaflet

# %%
import geopandas as gpd
import json
from pathlib import Path
import sys

sys.path.insert(0, '../src')
from visualization import VisualizationOps

DATA_RAW = Path('../data/raw')
DATA_GOLD = Path('../data/processed/gold')

print('✓ Imports successful')
