# %% [markdown]
# # 04: Clustering & H3 Hexagonal Binning
#
# This notebook demonstrates spatial aggregation using clustering and H3 hexagons.
#
# **Topics:**
# - K-means clustering on geospatial coordinates
# - H3 hexagonal binning (Uber's spatial indexing system)
# - Aggregate metrics by region
# - Feature engineering for ML

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import h3
from sklearn.cluster import KMeans
from pathlib import Path
import sys

sys.path.insert(0, '../src')

DATA_RAW = Path('../data/raw')
DATA_GOLD = Path('../data/processed/gold')

print('✓ Imports successful')
